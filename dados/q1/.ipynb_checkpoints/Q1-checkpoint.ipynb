# %%
#bib necessaria para a leitura da API
import requests

import numpy as np

#bib responsavel pela criação de data frames
import pandas as pd

#bib responsavel pela criação de gráficos 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#end point da API, como dois parametros, "start" e "number"

root = 'https://apitempo.inmet.gov.br/estacoes/T'
#usando uma requisição GET para exportação dos dados, estes que estão no formato JSON
data = requests.get(root)
data = data.json()

#primeira visualização dos dados, ainda no formato JSON
data

# %%
data = pd.json_normalize(data)
data
# Out:
#            CD_OSCAR               DC_NOME FL_CAPITAL DT_FIM_OPERACAO  \
# 0    0-2000-0-86765              ABROLHOS          N            None
# 1    0-2000-0-81755                ACARAU          N            None
# 2    0-2000-0-86827        AFONSO CLAUDIO       None            None
# 3    0-2000-0-86686              AGUA BOA          N            None
# 4    0-2000-0-86812            AGUA CLARA          N            None
# ..              ...                   ...        ...             ...
# 602  0-2000-0-86697  VITORIA DA CONQUISTA          N            None
# 603  0-2000-0-86815           VOTUPORANGA          N            None
# 604  0-2000-0-86940               XANXERE          N            None
# 605  0-2000-0-81896              XINGUARA          N            None
# 606  0-2000-0-81747               ZE DOCA          N            None
#
#     CD_SITUACAO  TP_ESTACAO   VL_LATITUDE                   CD_WSI  \
# 0          Pane  Automatica  -17.96305555  0-76-0-2906907000000408
# 1          Pane  Automatica    -3.1211111  0-76-0-2300200000000446
# 2      Operante  Automatica  -20.10416666  0-76-0-3200102000000478
# 3          Pane  Automatica  -14.01638888  0-76-0-5100201000000157
# 4      Operante  Automatica  -20.44444444  0-76-0-5000203000000463
# ..          ...         ...           ...                      ...
# 602    Operante  Automatica  -14.88638888  0-76-0-2933307000000204
# 603    Operante  Automatica  -20.40333333  0-76-0-3557105000000154
# 604    Operante  Automatica    -26.938666  0-76-0-4219507000000318
# 605    Operante  Automatica     -7.110518  0-76-0-1508407000000527
# 606    Operante  Automatica   -3.26916666  0-76-0-2114007000000596
#
#     CD_DISTRITO VL_ALTITUDE SG_ESTADO SG_ENTIDADE CD_ESTACAO  VL_LONGITUDE  \
# 0            04       20.93        BA       INMET       A422  -38.70333333
# 1            03       67.15        CE       INMET       A360  -40.08722221
# 2            06      507.48        ES       INMET       A657  -41.10694444
# 3            09         440        MT       INMET       A908  -52.21166666
# 4            07      323.63        MS       INMET       A756  -52.87583332
# ..          ...         ...       ...         ...        ...           ...
# 602          04      879.38        BA       INMET       A414  -40.80138888
# 603          07      510.37        SP       INMET       A729  -49.96611111
# 604          08      878.74        SC       INMET       A858     -52.39809
# 605          02         245        PA       INMET       A247    -49.926072
# 606          02        45.5        MA       INMET       A255  -45.65111111
#
#                 DT_INICIO_OPERACAO
# 0    2008-07-20T21:00:00.000-03:00
# 1    2009-04-21T21:00:00.000-03:00
# 2    2011-09-23T21:00:00.000-03:00
# 3    2006-12-15T21:00:00.000-03:00
# 4    2010-08-13T21:00:00.000-03:00
# ..                             ...
# 602  2007-05-31T21:00:00.000-03:00
# 603  2006-12-03T21:00:00.000-03:00
# 604  2008-03-14T21:00:00.000-03:00
# 605  2016-09-10T21:00:00.000-03:00
# 606  2019-09-17T21:00:00.000-03:00
#
# [607 rows x 15 columns]

# %%
root_14 = 'https://apitempo.inmet.gov.br/estacao/diaria/2021-11-29/2021-12-12/A301'

#usando uma requisição GET para exportação dos dados, estes que estão no formato JSON
data_14 = requests.get(root_14)
data_14 = data_14.json()

#primeira visualização dos dados, ainda no formato JSON
data_14
# Out:
# [{'UMID_MED': None,
#   'DT_MEDICAO': '2021-11-29',
#   'DC_NOME': 'RECIFE',
#   'UMID_MIN': None,
#   'TEMP_MED': None,
#   'CHUVA': None,
#   'VL_LATITUDE': '-8.05916666',
#   'TEMP_MIN': None,
#   'TEMP_MAX': None,
#   'UF': 'PE',
#   'VEL_VENTO_MED': None,
#   'CD_ESTACAO': 'A301',
#   'VL_LONGITUDE': '-34.95916666'},
#  {'UMID_MED': None,
#   'DT_MEDICAO': '2021-11-30',
#   'DC_NOME': 'RECIFE',
#   'UMID_MIN': None,
#   'TEMP_MED': None,
#   'CHUVA': None,
#   'VL_LATITUDE': '-8.05916666',
#   'TEMP_MIN': None,
#   'TEMP_MAX': None,
#   'UF': 'PE',
#   'VEL_VENTO_MED': None,
#   'CD_ESTACAO': 'A301',
#   'VL_LONGITUDE': '-34.95916666'},
#  {'UMID_MED': None,
#   'DT_MEDICAO': '2021-12-01',
#   'DC_NOME': 'RECIFE',
#   'UMID_MIN': None,
#   'TEMP_MED': None,
#   'CHUVA': None,
#   'VL_LATITUDE': '-8.05916666',
#   'TEMP_MIN': None,
#   'TEMP_MAX': None,
#   'UF': 'PE',
#   'VEL_VENTO_MED': None,
#   'CD_ESTACAO': 'A301',
#   'VL_LONGITUDE': '-34.95916666'},
#  {'UMID_MED': None,
#   'DT_MEDICAO': '2021-12-02',
#   'DC_NOME': 'RECIFE',
#   'UMID_MIN': None,
#   'TEMP_MED': None,
#   'CHUVA': None,
#   'VL_LATITUDE': '-8.05916666',
#   'TEMP_MIN': None,
#   'TEMP_MAX': None,
#   'UF': 'PE',
#   'VEL_VENTO_MED': None,
#   'CD_ESTACAO': 'A301',
#   'VL_LONGITUDE': '-34.95916666'},
#  {'UMID_MED': None,
#   'DT_MEDICAO': '2021-12-03',
#   'DC_NOME': 'RECIFE',
#   'UMID_MIN': None,
#   'TEMP_MED': None,
#   'CHUVA': None,
#   'VL_LATITUDE': '-8.05916666',
#   'TEMP_MIN': None,
#   'TEMP_MAX': None,
#   'UF': 'PE',
#   'VEL_VENTO_MED': None,
#   'CD_ESTACAO': 'A301',
#   'VL_LONGITUDE': '-34.95916666'},
#  {'UMID_MED': None,
#   'DT_MEDICAO': '2021-12-04',
#   'DC_NOME': 'RECIFE',
#   'UMID_MIN': None,
#   'TEMP_MED': None,
#   'CHUVA': None,
#   'VL_LATITUDE': '-8.05916666',
#   'TEMP_MIN': None,
#   'TEMP_MAX': None,
#   'UF': 'PE',
#   'VEL_VENTO_MED': None,
#   'CD_ESTACAO': 'A301',
#   'VL_LONGITUDE': '-34.95916666'},
#  {'UMID_MED': None,
#   'DT_MEDICAO': '2021-12-05',
#   'DC_NOME': 'RECIFE',
#   'UMID_MIN': None,
#   'TEMP_MED': None,
#   'CHUVA': None,
#   'VL_LATITUDE': '-8.05916666',
#   'TEMP_MIN': None,
#   'TEMP_MAX': None,
#   'UF': 'PE',
#   'VEL_VENTO_MED': None,
#   'CD_ESTACAO': 'A301',
#   'VL_LONGITUDE': '-34.95916666'},
#  {'UMID_MED': None,
#   'DT_MEDICAO': '2021-12-06',
#   'DC_NOME': 'RECIFE',
#   'UMID_MIN': None,
#   'TEMP_MED': None,
#   'CHUVA': None,
#   'VL_LATITUDE': '-8.05916666',
#   'TEMP_MIN': None,
#   'TEMP_MAX': None,
#   'UF': 'PE',
#   'VEL_VENTO_MED': None,
#   'CD_ESTACAO': 'A301',
#   'VL_LONGITUDE': '-34.95916666'},
#  {'UMID_MED': None,
#   'DT_MEDICAO': '2021-12-07',
#   'DC_NOME': 'RECIFE',
#   'UMID_MIN': None,
#   'TEMP_MED': None,
#   'CHUVA': None,
#   'VL_LATITUDE': '-8.05916666',
#   'TEMP_MIN': None,
#   'TEMP_MAX': None,
#   'UF': 'PE',
#   'VEL_VENTO_MED': None,
#   'CD_ESTACAO': 'A301',
#   'VL_LONGITUDE': '-34.95916666'},
#  {'UMID_MED': None,
#   'DT_MEDICAO': '2021-12-08',
#   'DC_NOME': 'RECIFE',
#   'UMID_MIN': None,
#   'TEMP_MED': None,
#   'CHUVA': None,
#   'VL_LATITUDE': '-8.05916666',
#   'TEMP_MIN': None,
#   'TEMP_MAX': None,
#   'UF': 'PE',
#   'VEL_VENTO_MED': None,
#   'CD_ESTACAO': 'A301',
#   'VL_LONGITUDE': '-34.95916666'},
#  {'UMID_MED': None,
#   'DT_MEDICAO': '2021-12-09',
#   'DC_NOME': 'RECIFE',
#   'UMID_MIN': None,
#   'TEMP_MED': None,
#   'CHUVA': None,
#   'VL_LATITUDE': '-8.05916666',
#   'TEMP_MIN': None,
#   'TEMP_MAX': None,
#   'UF': 'PE',
#   'VEL_VENTO_MED': None,
#   'CD_ESTACAO': 'A301',
#   'VL_LONGITUDE': '-34.95916666'},
#  {'UMID_MED': None,
#   'DT_MEDICAO': '2021-12-10',
#   'DC_NOME': 'RECIFE',
#   'UMID_MIN': None,
#   'TEMP_MED': None,
#   'CHUVA': None,
#   'VL_LATITUDE': '-8.05916666',
#   'TEMP_MIN': None,
#   'TEMP_MAX': None,
#   'UF': 'PE',
#   'VEL_VENTO_MED': None,
#   'CD_ESTACAO': 'A301',
#   'VL_LONGITUDE': '-34.95916666'},
#  {'UMID_MED': None,
#   'DT_MEDICAO': '2021-12-11',
#   'DC_NOME': 'RECIFE',
#   'UMID_MIN': None,
#   'TEMP_MED': None,
#   'CHUVA': None,
#   'VL_LATITUDE': '-8.05916666',
#   'TEMP_MIN': None,
#   'TEMP_MAX': None,
#   'UF': 'PE',
#   'VEL_VENTO_MED': None,
#   'CD_ESTACAO': 'A301',
#   'VL_LONGITUDE': '-34.95916666'},
#  {'UMID_MED': None,
#   'DT_MEDICAO': '2021-12-12',
#   'DC_NOME': 'RECIFE',
#   'UMID_MIN': None,
#   'TEMP_MED': None,
#   'CHUVA': None,
#   'VL_LATITUDE': '-8.05916666',
#   'TEMP_MIN': None,
#   'TEMP_MAX': None,
#   'UF': 'PE',
#   'VEL_VENTO_MED': None,
#   'CD_ESTACAO': 'A301',
#   'VL_LONGITUDE': '-34.95916666'}]

# %%
data_14 = pd.json_normalize(data_14)
data_14
# Out:
#    UMID_MED  DT_MEDICAO DC_NOME UMID_MIN TEMP_MED CHUVA  VL_LATITUDE TEMP_MIN  \
# 0      None  2021-11-29  RECIFE     None     None  None  -8.05916666     None
# 1      None  2021-11-30  RECIFE     None     None  None  -8.05916666     None
# 2      None  2021-12-01  RECIFE     None     None  None  -8.05916666     None
# 3      None  2021-12-02  RECIFE     None     None  None  -8.05916666     None
# 4      None  2021-12-03  RECIFE     None     None  None  -8.05916666     None
# 5      None  2021-12-04  RECIFE     None     None  None  -8.05916666     None
# 6      None  2021-12-05  RECIFE     None     None  None  -8.05916666     None
# 7      None  2021-12-06  RECIFE     None     None  None  -8.05916666     None
# 8      None  2021-12-07  RECIFE     None     None  None  -8.05916666     None
# 9      None  2021-12-08  RECIFE     None     None  None  -8.05916666     None
# 10     None  2021-12-09  RECIFE     None     None  None  -8.05916666     None
# 11     None  2021-12-10  RECIFE     None     None  None  -8.05916666     None
# 12     None  2021-12-11  RECIFE     None     None  None  -8.05916666     None
# 13     None  2021-12-12  RECIFE     None     None  None  -8.05916666     None
#
#    TEMP_MAX  UF VEL_VENTO_MED CD_ESTACAO  VL_LONGITUDE
# 0      None  PE          None       A301  -34.95916666
# 1      None  PE          None       A301  -34.95916666
# 2      None  PE          None       A301  -34.95916666
# 3      None  PE          None       A301  -34.95916666
# 4      None  PE          None       A301  -34.95916666
# 5      None  PE          None       A301  -34.95916666
# 6      None  PE          None       A301  -34.95916666
# 7      None  PE          None       A301  -34.95916666
# 8      None  PE          None       A301  -34.95916666
# 9      None  PE          None       A301  -34.95916666
# 10     None  PE          None       A301  -34.95916666
# 11     None  PE          None       A301  -34.95916666
# 12     None  PE          None       A301  -34.95916666
# 13     None  PE          None       A301  -34.95916666
